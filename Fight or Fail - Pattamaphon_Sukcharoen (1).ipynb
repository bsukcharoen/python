# %%
"""
Created on Thu 17 Oct 10.00AM

@author: Pattamaphon Sukcharoen
"""

"""
    DocString:
    
    A)Introduction: 
    This is a gameshow that you may need your luck and knowledge to answer 
    the question. The show has three level and there will be a jackpot level for any
    contestant who pass three level.
    
    Round 1: Guessing top 5 answer 5.
    Round 2: Guessing top 3 answer 3
    Round 3: Global questionaire
    
    B) Known Bugs and/or Errors:
    None.
    
"""

from sys import exit 
from random import randint

#introduction host 
host_name = input('host name : ')
host_name = host_name.upper()
    
print(f"""
            Hello everyone!!! Welcome back to “FIGHT or FAIL” a game that need 
                  your knowledge ,your sense and your luck with me {host_name}! 
""")
    
input('Press enter to continue...\n')
    
print(f"""

            {host_name}:Please welcome our contestant to the show !!!

            What's your name ?
""")
#introduction contestant
contestant_name = input('contestant name : ')
contestant_name = contestant_name.upper()

print(f"""

            {host_name}: Alright!!! , Are you ready to win the JACKPOT {contestant_name} ???
            """)

input('Press enter to continue...\n')

print(f"""                  
            {host_name} :For the first round you will need to provide top 5 answers
            from the given question. You will lose the game,if you make mistake 
            over 2 times in this round.""")

input(f"""

Press enter to start the game...\n""")

print(f"""
            {host_name}:Question 1...
            
            What are the top 5 popular fruit in United State of America?

            HINT...one of them is yellow,red,purple,orange and another red colors.
""")

#create the list of the answer1
pop_fruits_1 = ['a banana','banana','bananas']
pop_fruits_2 = ['an apple','apple','apples']
pop_fruits_3 = ['a grape','grape','grapes']
pop_fruits_4 = ['a strawberry','strawberry','strawberries']
pop_fruits_5 = ['an orange','orange','oranges']
pop_all = [pop_fruits_1, pop_fruits_2, pop_fruits_3, pop_fruits_4, pop_fruits_5]

#create the list of the answer2
pop_dessert_1 = ['a donut','a doughnut','doughnuts''donuts','donut']
pop_dessert_2 = ['an ice cream','ice cream','icecream']
pop_dessert_3 = ['a cake','cake']
pop_all_dessert = [pop_dessert_1, pop_dessert_2, pop_dessert_3]


chances = 3
question_no = 1

#Round1 guessing the answer from the list of answer1
def start():
    global chances
    global question_no

#looping until it has no inner list in the list

    while question_no <= 8:
        if pop_all == []:
            print(f"""
                            
            {host_name} : Awesome {contestant_name}! Keep it up !!!
""")
#if completed all ansert will move to the next round
            round_2()
            
        answer_1 = input(f"""
                         {str(question_no)})""")
        answer_1 = answer_1.lower()
        while True:

            for item in pop_all:
                for item_inner in item:
                    if answer_1 == item_inner:
                        print("""\t\t\t\t\t\t\t\tcorrect""")
                        pop_all.remove(item)
                        question_no += 1
                        start()    
                        break
#2 chances for making mistake in this round                       
            if chances > 1:
                chances -= 1
                print(f"""
                                        Incorrect, you have {str(chances)} chances left""")
                question_no += 1
                start()
                break

            elif chances == 1:
                chances -= 1
                print(f"""
                                        Incorrect, you have {str(chances)} chances left""")

#if making mistake over 2 times , it will reach to fail() and end this game                
                fail()

#Round2 introduction
def round_2(): 
    
    input('Press enter to start ROUND 2...\n')


    print(f"""
            {host_name}:In this question you will need to provide top 3 answers
            from the given question.{contestant_name}, this round you can make only one 
            mistake, otherwise you will fail this game.
""")

    input(f"""
Press enter start the game...\n""")


    print(f"""
            {host_name}:Question 2...
            
            What is the most popular dessert in America?
            
            Sound difficult, isn't it? But today, I have a good mood
            and want you to win the jackpot!so I will give you a hint.

    """)
    #https://www.insider.com/most-popular-food-trends-2017-12

    input(f"""Press enter see the hint...\n""")

    print(f"""
                                      HINT!
                                    
                                   1) a hole            
                                   2) a cone        
                                   3) Birthday! 

                    Remember! You can make only one mistake. 
    """)
    
    input(f"""Press enter to answer...\n""")
    start_2()

chances_2 = 2   

#Guessing answer question 2
def start_2():
    global question_no
    global chances_2

    while question_no <= 13:
        if pop_all_dessert == []:
            print(f"""
            
                    The jackpot is only one more step!!! {contestant_name}
                    """)
                    
            input("""Press enter to start the final round...\n""")
            
            round_3()#if completed , it will reach to the next round
            
        answer_2 = input(f"""
                         {str(question_no)})""")
        answer_2 = answer_2.lower()
        while True:

            for item in pop_all_dessert:
                for item_inner in item:
                    if answer_2 == item_inner:
                        print("""\t\t\t\t\t\t\t\tcorrect""")
                        pop_all_dessert.remove(item)
                        question_no += 1
                        start_2() 
                        
#only one chances to take mistake.
            if chances_2 > 1:
                print(f"""
                                    Incorrect, you can't get any more mistake""")
                chances_2 -= 1
                question_no += 1
                start_2()

            elif chances_2 == 1:
                fail()#move to failed and end this game

#answering difficult question , and has to chance to make mistake
def round_3():
    
    print(f"""
    
        {host_name}:This is going to be a tough question, are you excited?

     """)

    input(f"""Press enter to continue...\n""")


    print(f"""
            {host_name}:Question 3...

            What is the greeting word in Thai ?

                         1) Sa-Wad-Dee
                         2) Konnichiwa
                         3) Sa-Bai-Dee
                         4) Kamusta

    """)
    
    print("""Put ...yes ...if you want to anwser it now 
    """)
    print("""Put ...no...if you need some help with 50:50
    """)
    last_answer()
    
def last_answer():   
    your_option = input("Please tell me what you decided (yes/no) ...\n")
    your_option = your_option.lower()
    if your_option == "yes":
        answer = input("Press 1 ,2 ,3 or 4 to answer the question")
        if answer == "1":
            jackpot()
        elif answer == "2" or "3" or "4": 
            fail()
        else:
            last_answer
    elif your_option == "no":
        print(f"""

        {host_name}:So...If you lucky, you will know the answer easily from 50:50

        However,if you won the jackpot , the reward will worth just half of it.

        Do you want to use 50:50?
        """)   
        yes_or_no = input("""\nWill you take this option,50:50...Press (yes/no) ...""")
        if yes_or_no == "yes":
            fifty_fifty()

        elif yes_or_no == "no":
            answer = input("Press 1 ,2 ,3 or 4 to answer the question")
            if answer == "1":
                jackpot()
            elif answer == "2" or "3" or "4": 
                fail()
            else:
                last_question()
            

#random number to show the options of answer
def fifty_fifty():
    
    input(f"""Press enter to see the option for 50:50... \n""")

    import numpy as np
    random_1 = np.random.randint(0,2)
    
    if random_1 == 0:
        print(f"""

        One of 50:50 says: Sorry I am not sure , but there is Dee in the word. 
        """)
        answer = input("Press 1 ,2 ,3 or 4 to answer the question")
    
        if answer != "1":
            fail()  
        elif answer == "1":
            jackpot_2()

    elif random_1 > 0:
        print(f"""

        One of the 50:50 says : 100% sure, It's Sa-Wad-Dee' 
        """)
        answer = input("Press 1 ,2 ,3 or 4 to answer the question")
        
        if answer == "1":
            jackpot_2()
        elif answer != "1":
            fail()     
            
def fail():
    print(f"""
            {host_name}:Sorry, you have fail this show... Thank you for joining us today""")
    exit()
    
              
def jackpot():
    print(f"""
            {host_name}:You did it!!! Let's roll the wheel to see the jackpot reward
    """)
        
    a_one_dollar = 1
    a_ten_thou_dollar = 2
    a_hun_thou_dollar = 3
    a_mill_dollar = 4
    
    input(f"""
Press enter to roll the jackpot...\n""")
    
#countdown before the jackpot    
    import time
    for i in range(3,0,-1):
        print("""
                                        """ + str(i))
        time.sleep(1)
        print("")
                
    Roll_jackpot = np.random.randint(0,4)
    if Roll_jackpot == 1 :     
        print(f"""

        {host_name} :"$1", I am really sorry {contestant_name} that you not lucky enough today """)

    elif Roll_jackpot == 2 :
        print(f"""

            {host_name} : Ohhhh! {contestant_name} You got $10,000 today  """)

    elif Roll_jackpot == 3 :
        print(f"""

            {host_name} : Oh my goodness! You won $100,000 today.Congratuation!!!""") 
    elif Roll_jackpot == 4 :
        print(f"""

            {host_name} : Congratulations !!!! {contestant_name} You're taking $1,000,000 back home""")
    endgame()
    
def jackpot_2(): #reward worth half of it.
    print(f"""
            {host_name}:You did it!!! Let's roll the wheel to see the jackpot reward
    """)
    input(f"""
Press enter to roll the jackpot...\n""")
    import time
    for i in range(3,0,-1):
        print("""
                                        """ + str(i))
        time.sleep(1)
        print("")
    
    a_one_dollar = 1
    a_ten_thou_dollar = 2
    a_hun_thou_dollar = 3
    a_mill_dollar = 4
    
    Roll_jackpot = np.random.randint(0,4)
    if Roll_jackpot == 1 :     
        print(f"""
    
            {host_name} :"$1/2", I am really sorry {contestant_name} that you not lucky enough today """)

    elif Roll_jackpot == 2 :
        print(f"""
    
            {host_name} : Ohhhh! {contestant_name} You got $10,000/2 today  """)
    
    elif Roll_jackpot == 3 :
        print(f"""
    
            {host_name} : Oh my goodness! You won $100,000/2 today.Congratuation!!!""") 
    elif Roll_jackpot == 4 :
        print(f"""
    
            {host_name} : Congratulations !!!! {contestant_name} You're taking $1,000,000/2 back home""")
        
    endgame()
    
    
def endgame():
    print(f"""
            {host_name}: Thank you for joining us today, and I will see you soon
                                  
                                    GOODBYE !!!!""")
    exit()#win or lose, exit here


    


start()#running start game
# Out:
# host name : Boss
#
#             Hello everyone!!! Welcome back to “FIGHT or FAIL” a game that need
#                   your knowledge ,your sense and your luck with me BOSS!
#
# Press enter to continue...
#
#
#
#             BOSS:Please welcome our contestant to the show !!!
#
#             What's your name ?
#
# contestant name : pat
#
#
#             BOSS: Alright!!! , Are you ready to win the JACKPOT PAT ???
#
# Press enter to continue...
#
#
#             BOSS :For the first round you will need to provide top 5 answers
#             from the given question. You will lose the game,if you make mistake
#             over 2 times in this round.
#
#
# Press enter to start the game...
#
#
#             BOSS:Question 1...
#
#             What are the top 5 popular fruit in United State of America?
#
#             HINT...one of them is yellow,red,purple,orange and another red colors.
#
#
#                          1)apple
# 								correct
#
#                          2)strawberry
# ...
